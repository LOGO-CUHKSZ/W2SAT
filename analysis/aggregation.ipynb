# %%
import pandas as pd

data = pd.read_csv('./aggregation.csv')
data
# Out:
#        Model  VIGclust.  LIGclust.  VIGmod.  LIGmod.  VCGmod.  LCGmod.
# 0   Training      0.582      0.351    0.521    0.562    0.637    0.587
# 1    SAT-GEN      0.513      0.340    0.477    0.542    0.632    0.537
# 2         PS      0.818      0.616    0.678    0.732    0.832    0.588
# 3         CA      0.368      0.247    0.412    0.499    0.629    0.502
# 4      W2SAT      0.539      0.435    0.520    0.576    0.664    0.527
# 5   Training      0.428      0.357    0.469    0.538    0.784    0.719
# 6    SAT-GEN      0.397      0.331    0.433    0.524    0.695    0.607
# 7         PS      0.658      0.579    0.439    0.526    0.755    0.592
# 8         CA      0.234      0.120    0.401    0.454    0.601    0.525
# 9      W2SAT      0.429      0.356    0.458    0.543    0.718    0.558
# 10  Training      0.493      0.327    0.660    0.783    0.768    0.762
# 11   SAT-GEN      0.417      0.342    0.604    0.772    0.758    0.674
# ...

# %%
gb = data.groupby('Model')
c = gb.agg('mean')
c
# Out:
#           VIGclust.  LIGclust.  VIGmod.  LIGmod.  VCGmod.  LCGmod.
# Model
# CA           0.2406     0.1634   0.5590   0.5992   0.7012   0.5482
# PS           0.6356     0.5246   0.6626   0.7242   0.8434   0.6200
# SAT-GEN      0.4198     0.3212   0.5496   0.6326   0.7150   0.6148
# Training     0.5162     0.3594   0.6122   0.6568   0.7554   0.6956
# W2SAT        0.4902     0.4192   0.5950   0.6684   0.7434   0.5866
